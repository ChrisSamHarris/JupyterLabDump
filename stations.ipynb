# %%
import pandas as pd
df = pd.read_csv("stations.txt", skiprows=17)

# %%
df.columns
# Out:
# Index(['STAID', 'STANAME                                 ', 'CN', '      LAT',
#        '       LON', 'HGHT'],
#       dtype='object')

# %%
df[['STAID','STANAME                                 ']]
# Out:
#       STAID      STANAME
# 0         1  VAEXJOE
# 1         2  FALUN
# 2         3  STENSELE
# 3         4  LINKOEPING
# 4         5  LINKOEPING-MALMSLAETT
# ...     ...                                           ...
# 6595  25163  KORGASEN
# 6596  25825  RAGNAROKK
# 6597  25826  FINNESVATNET
# 6598  25827  KOMMAGDALEN
# 6599  25828  HUBEHYTTA
#
# [6600 rows x 2 columns]

# %%
df['STANNAME'] = df['STANAME                                 ']
df
# Out:
#       STAID      STANAME                                     CN        LAT  \
# 0         1  VAEXJOE                                       SE    +56:52:00
# 1         2  FALUN                                         SE    +60:37:00
# 2         3  STENSELE                                      SE    +65:04:00
# 3         4  LINKOEPING                                    SE    +58:24:00
# 4         5  LINKOEPING-MALMSLAETT                         SE    +58:24:00
# ...     ...                                           ...   ...        ...
# 6595  25163  KORGASEN                                      NO    +69:56:11
# 6596  25825  RAGNAROKK                                     NO    +70:22:00
# 6597  25826  FINNESVATNET                                  NO    +70:14:48
# 6598  25827  KOMMAGDALEN                                   NO    +70:17:35
# 6599  25828  HUBEHYTTA                                     NO    +70:19:19
#
#              LON  HGHT                                      STANNAME
# ...
